# %%
import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

# %%
import pandas as pd
hhdata1=pd.read_csv("s3://1stDLBucket/hhdata.csv", sep=";", storage_options={
"key": '00369a8ecf2122c0000000001',
"secret": 'K003l9Z8bH6j0pGzDXVDylPUNh7S040',
"endpoint_url": "https://s3.eu-central-003.backblazeb2.com"
}
)
hhdata1.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 hhdata1=pd.read_csv("s3://1stDLBucket/hhdata.csv", sep=";", storage_options={
#       3 "key": '00369a8ecf2122c0000000001',
#       4 "secret": 'K003l9Z8bH6j0pGzDXVDylPUNh7S040',
#       5 "endpoint_url": "https://s3.eu-central-003.backblazeb2.com"
#
# ...
